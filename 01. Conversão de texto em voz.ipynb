# %% [markdown]
# # Conversor de texto para áudio

# %%
#pip install pyttsx3

# %%
#Importando biblioteca
import pyttsx3

# %%
#leitura do texto que esta guardado em um arquivo .txt
arquivo = open('doc.txt', 'r', encoding="utf8")
texto = arquivo.read()

# %%
#inicia biblioteca
engine = pyttsx3.init()
voices = engine.getProperty('voices')

# %%
#definição da voz em português. No caso em questão a língua brasileira estava indexada em 53
#rate muda a velocidade da leitura(quando menor mais lento)
engine.setProperty('voice', voices[53].id)
rate = engine.getProperty('rate')
engine.setProperty('rate', rate-25)

# %%
#Escrever o texto na tela
#Definir o texto que será lido
#Ler o texto
#Fechar o modo de leitura do arquivo

print(texto)
engine.say(texto)
engine.runAndWait()
f.close()
# Out:
# Em linguística, a noção de texto é ampla e ainda aberta a uma definição mais precisa.

# %% [markdown]
# ### Caso precise verificar qual a indexação da língua em seu pc, use o loop abaixo.

# %%
#Verificar vozes do sistema
for voice in voices:
    if voice.name=='brazil':
        engine.setProperty('voice', voice.id)
    print(voice, voice.id)
# Out:
# <Voice id=afrikaans
#           name=afrikaans
#           languages=[b'\x05af']
#           gender=male
#           age=None> afrikaans
# <Voice id=aragonese
#           name=aragonese
#           languages=[b'\x05an']
#           gender=male
#           age=None> aragonese
# <Voice id=bulgarian
#           name=bulgarian
#           languages=[b'\x05bg']
#           gender=None
#           age=None> bulgarian
# <Voice id=bosnian
#           name=bosnian
#           languages=[b'\x05bs']
#           gender=male
#           age=None> bosnian
# <Voice id=catalan
#           name=catalan
#           languages=[b'\x05ca']
#           gender=male
#           age=None> catalan
# <Voice id=czech
#           name=czech
#           languages=[b'\x05cs']
#           gender=male
#           age=None> czech
# <Voice id=welsh
#           name=welsh
#           languages=[b'\x05cy']
#           gender=male
#           age=None> welsh
# <Voice id=danish
#           name=danish
# ...
